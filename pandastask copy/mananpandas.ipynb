# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
matches=pd.read_csv("matches.csv")
deliveries=pd.read_csv("deliveries.csv")

# %%
columns=matches.columns
index=matches.index
data=matches.to_numpy()

# %%
matches
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
# Q1
matches[matches.eq(2008)].season.count()
# Out:
# 58

# %%
#Q2
print(matches['city'].value_counts().idxmax())
print(matches['city'].value_counts().idxmin())
# Out:
# Mumbai
# Bloemfontein

# %%
#Q3
matches.city.value_counts()
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
#Q4
print(matches["toss_winner"].value_counts().idxmax())
print(matches["toss_winner"].value_counts().idxmin())
# Out:
# Mumbai Indians
# Rising Pune Supergiant

# %%
#Q5
matches.groupby(["toss_winner",'toss_decision']).nunique()
# Out:
#                                            id  season  city  date  team1  \
# toss_winner                 toss_decision
# Chennai Super Kings         bat            48      10    18    48      1
#                             field          41      10    16    41      8
# Deccan Chargers             bat            24       5    16    24      1
#                             field          19       5    10    19      7
# Delhi Capitals              bat             2       1     1     2      1
#                             field           8       1     7     8      6
# Delhi Daredevils            bat            29      10    11    29      1
#                             field          51      11    18    51     10
# Gujarat Lions               bat             1       1     1     1      1
#                             field          14       2     7    14      6
# Kings XI Punjab             bat            26      10    15    26      1
# ...

# %%
# Q6
matches.result.value_counts()
# Out:
# result
# normal       743
# tie            9
# no result      4
# Name: count, dtype: int64

# %%
# Q7
matches.loc[matches['result']=='tie',['team1','team2']]
# Out:
#                            team1                        team2
# 33                 Gujarat Lions               Mumbai Indians
# 125             Rajasthan Royals        Kolkata Knight Riders
# 189              Kings XI Punjab          Chennai Super Kings
# 387  Royal Challengers Bangalore          Sunrisers Hyderabad
# 400             Delhi Daredevils  Royal Challengers Bangalore
# 475             Rajasthan Royals        Kolkata Knight Riders
# 535             Rajasthan Royals              Kings XI Punjab
# 705        Kolkata Knight Riders               Delhi Capitals
# 746               Mumbai Indians          Sunrisers Hyderabad

# %%
# Q8
# matches.loc[matches['win_by_runs']]
matches.loc[matches['win_by_runs'].idxmax(), 'winner']
# Out:
# 'Mumbai Indians'

# %%
# Q9
matches.loc[matches['win_by_runs'].idxmin(), 'winner']
# Out:
# 'Rising Pune Supergiant'

# %%
# Q10
play=matches.player_of_match.value_counts()
print(play[play > 3].index.tolist())
# Out:
# ['CH Gayle', 'AB de Villiers', 'RG Sharma', 'MS Dhoni', 'DA Warner', 'YK Pathan', 'SR Watson', 'SK Raina', 'G Gambhir', 'MEK Hussey', 'AM Rahane', 'V Kohli', 'V Sehwag', 'DR Smith', 'AD Russell', 'A Mishra', 'JH Kallis', 'KA Pollard', 'SE Marsh', 'AT Rayudu', 'SP Narine', 'Harbhajan Singh', 'SR Tendulkar', 'RA Jadeja', 'UT Yadav', 'Rashid Khan', 'RV Uthappa', 'AC Gilchrist', 'M Vijay', 'RR Pant', 'S Dhawan', 'SL Malinga', 'A Nehra', 'BJ Hodge', 'HH Pandya', 'SC Ganguly', 'SPD Smith', 'PA Patel', 'KC Sangakkara', 'DPMD Jayawardene', 'BB McCullum', 'JP Faulkner', 'AJ Finch', 'DW Steyn', 'Yuvraj Singh', 'SV Samson', 'GJ Maxwell', 'JJ Bumrah', 'Sandeep Sharma', 'JD Unadkat', 'JC Buttler', 'B Kumar', 'KL Rahul', 'KD Karthik', 'JP Duminy', 'MK Pandey', 'NM Coulter-Nile', 'AR Patel', 'N Rana', 'F du Plessis', 'SK Warne', 'CA Lynn', 'SS Iyer', 'ML Hayden', 'KH Pandya']

# %%
# Q11
matches.player_of_match.value_counts().idxmax()
# Out:
# 'CH Gayle'

# %%
# Q12
matches.loc[matches['win_by_runs'].idxmin(), 'venue']
# Out:
# 'Maharashtra Cricket Association Stadium'

# %%
# Q13
matches.loc[matches['win_by_runs'].idxmin(), 'venue']
# Out:
# 'Maharashtra Cricket Association Stadium'

# %%
# Q14
print(matches.umpire1.value_counts().idxmax())
print(matches.umpire2.value_counts().idxmax())
# Out:
# HDPK Dharmasena
# C Shamshuddin

# %%
# Q15
#matches.where[set(matches['season'])==matches['season'].]
#for a in set(matches['season']):
for i in range(8):
    pd=matches[matches['season']==matches['season'].value_counts().index[i]]
    print(pd['id'])
# Out:
# 381    382
# 382    383
# 383    384
# 384    385
# 385    386
#       ...
# 452    453
# 453    454
# 454    455
# 455    456
# 456    457
# Name: id, Length: 76, dtype: int64
# 307    308
# 308    309
# 309    310
# 310    311
# 311    312
#       ...
# 376    377
# 377    378
# 378    379
# 379    380
# 380    381
# Name: id, Length: 74, dtype: int64
# 234    235
# 235    236
# 236    237
# 237    238
# 238    239
#       ...
# 302    303
# 303    304
# 304    305
# 305    306
# 306    307
# Name: id, Length: 73, dtype: int64
# 174    175
# 175    176
# 176    177
# 177    178
# 178    179
# 179    180
# 180    181
# 181    182
# 182    183
# 183    184
# 184    185
# 185    186
# 186    187
# 187    188
# 188    189
# 189    190
# 190    191
# 191    192
# 192    193
# 193    194
# 194    195
# 195    196
# 196    197
# 197    198
# 198    199
# 199    200
# 200    201
# 201    202
# 202    203
# 203    204
# 204    205
# 205    206
# 206    207
# 207    208
# 208    209
# ...

# %%
totalRunsPerMatch = extraData.groupby('match_id')['total_runs'].sum()
mergedData = data.merge(totalRunsPerMatch, left_on='id', right_index=True, how='inner')
maxRunsPerYear = mergedData.groupby('season')['total_runs'].max()
maxRunsPerYear
# Out:
# season
# 2008    447
# 2009    377
# 2010    469
# 2011    433
# 2012    413
# 2013    396
# 2014    428
# 2015    431
# 2016    409
# 2017    453
# 2018    471
# 2019    445
# Name: total_runs, dtype: int64

# %%
# Q16
matches.groupby(['season'])['win_by_runs'].sum()
# Out:
# season
# 2008     705
# 2009     764
# 2010     976
# 2011    1098
# 2012     960
# 2013    1241
# 2014     644
# 2015     850
# 2016     676
# 2017     788
# 2018     675
# 2019     665
# Name: win_by_runs, dtype: int64

# %%
# Q17
matches.toss_winner.value_counts()
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
# Q18
matches.plot(x="toss_decision", y="season", kind="line", figsize=(9, 8))
plt.show()

# %%
# Q19
dele=deliveries
x=dele['dismissal_kind'].where(dele['dismissal_kind']!='nan').value_counts().index
y=dele['dismissal_kind'].where(dele['dismissal_kind']!='nan').value_counts()
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
# Q20
print(matches.win_by_runs.nlargest(10))
m,c = np.polyfit(matches.win_by_runs.nlargest(10), matches.index[matches.win_by_runs.nlargest(10)], 1)
fit=m*matches.win_by_runs.nlargest(10)+c
plt.scatter(matches.win_by_runs.nlargest(10),matches.index[matches.win_by_runs.nlargest(10)])
plt.plot(matches.win_by_runs.nlargest(10),fit,'r')
# Out:
# 43     146
# 619    144
# 59     140
# 556    138
# 410    130
# 706    118
# 295    111
# 114    105
# 676    102
# 182     98
# Name: win_by_runs, dtype: int64

# %%
# Q21
deliveries
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
# Q22
matches.team1.value_counts()+matches.team2.value_counts()
# Out:
# Chennai Super Kings            164
# Deccan Chargers                 75
# Delhi Capitals                  16
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 187
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# Name: count, dtype: int64

# %%
# Q23
X=matches.winner.value_counts()
Y=matches.index[matches.winner.value_counts()]
plt.bar(X,Y)
# Out:
# <BarContainer object of 15 artists>

# %%
# Q24
matches.plot(x="toss_decision", y="season", kind="line", figsize=(9, 8))
# Out:
# <Axes: xlabel='toss_decision'>

# %%
# Q25
ratio=matches.result.value_counts()['normal']/matches.result.count()
print(ratio)
# Out:
# 0.9828042328042328

# %%
# Q26
matches.groupby(['toss_decision'])['toss_winner'].value_counts()
# Out:
# toss_decision  toss_winner
# bat            Chennai Super Kings            48
#                Mumbai Indians                 44
#                Rajasthan Royals               32
#                Kolkata Knight Riders          30
#                Delhi Daredevils               29
#                Kings XI Punjab                26
#                Deccan Chargers                24
#                Royal Challengers Bangalore    20
#                Sunrisers Hyderabad            20
#                Pune Warriors                  11
#                Rising Pune Supergiants         3
#                Kochi Tuskers Kerala            3
#                Delhi Capitals                  2
#                Gujarat Lions                   1
# field          Kolkata Knight Riders          62
#                Royal Challengers Bangalore    61
#                Kings XI Punjab                55
#                Mumbai Indians                 54
#                Delhi Daredevils               51
# ...
