# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('matches.csv')
fd = pd.read_csv('deliveries.csv')

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %% [markdown]
# #q1
# b=df.season.ge(2008).sum()
# a=df.season.ge(2009).sum()
# b-a

# %%
#q2
print(df['city'].value_counts().to_frame().iloc[-1].name)
print(df['city'].value_counts().to_frame().iloc[0].name)
# Out:
# Bloemfontein
# Mumbai

# %%
#q3
df['city'].value_counts().to_frame()
# Out:
#                 count
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2

# %%
#q4
print(df['toss_winner'].value_counts().to_frame().iloc[0].name)
print(df['toss_winner'].value_counts().to_frame().iloc[-1].name)
# Out:
# Mumbai Indians
# Rising Pune Supergiant

# %%
#q5
df.toss_decision
# Out:
# 0      field
# 1      field
# 2      field
# 3      field
# 4        bat
#        ...
# 751    field
# 752      bat
# 753    field
# 754    field
# 755      bat
# Name: toss_decision, Length: 756, dtype: object

# %%
#q6
df['result'].value_counts()
# Out:
# result
# normal       743
# tie            9
# no result      4
# Name: count, dtype: int64

# %%
#q7
another = df
p=another.drop(np.where(df.result!='tie')[0])
a=p.team1
b=p.team2
f=list(a)
e=list(b)
d=e+f
set(d)
# Out:
# {'Chennai Super Kings',
#  'Delhi Capitals',
#  'Delhi Daredevils',
#  'Gujarat Lions',
#  'Kings XI Punjab',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Rajasthan Royals',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad'}

# %%
#q8
a=df.win_by_runs.max()
black=df
c=black.drop(np.where(df.win_by_runs!=a)[0])
c.winner
# Out:
# 43    Mumbai Indians
# Name: winner, dtype: object

# %%
#q9
a=df.win_by_runs.min()
black=df
c=black.drop(np.where(df.win_by_runs!=a)[0])
set(c.winner)
# Out:
# {'Chennai Super Kings',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Delhi Daredevils',
#  'Gujarat Lions',
#  'Kings XI Punjab',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Pune Warriors',
#  'Rajasthan Royals',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiants',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad',
#  nan}

# %%
#q10
black=df
c=df["player_of_match"].value_counts().to_frame()
d=black.drop(np.where(df["player_of_match"].value_counts().to_frame()<3)[0])
set(d.player_of_match)
# Out:
# {'A Chandila',
#  'A Joseph',
#  'A Kumble',
#  'A Mishra',
#  'A Nehra',
#  'A Symonds',
#  'A Zampa',
#  'AB Dinda',
#  'AB de Villiers',
#  'AC Gilchrist',
#  'AD Mascarenhas',
#  'AD Russell',
#  'AJ Finch',
#  'AJ Tye',
#  'AM Rahane',
#  'AP Tare',
#  'AR Patel',
#  'AS Rajpoot',
#  'AS Yadav',
#  'AT Rayudu',
#  'Azhar Mahmood',
#  'B Kumar',
#  'B Lee',
#  'B Stanlake',
#  'BA Bhatt',
#  'BA Stokes',
#  'BB McCullum',
#  'BCJ Cutting',
#  'BJ Hodge',
#  'BW Hilfenhaus',
#  'CA Lynn',
#  'CH Gayle',
#  'CH Morris',
#  'CJ Anderson',
#  'CL White',
#  'CR Brathwaite',
#  'DA Miller',
#  'DA Warner',
#  'DE Bollinger',
#  'DJ Bravo',
#  'DJ Hooda',
#  'DJ Hussey',
#  'DJG Sammy',
#  'DL Chahar',
#  'DPMD Jayawardene',
#  'DR Smith',
#  'DW Steyn',
#  'EJG Morgan',
#  'F du Plessis',
#  'G Gambhir',
#  'GD McGrath',
#  'GH Vihari',
#  'GJ Bailey',
#  'GJ Maxwell',
#  'H Gurney',
#  'HH Pandya',
#  'HM Amla',
#  'HV Patel',
#  'Harbhajan Singh',
#  'Harmeet Singh',
#  'I Sharma',
# ...

# %%
#q11
df["player_of_match"].value_counts().to_frame().iloc[0].name
# Out:
# 'CH Gayle'

# %%
#q12
a=df.win_by_runs.max()
black=df
c=black.drop(np.where(df.win_by_runs!=a)[0])
c.venue
# Out:
# 43    Feroz Shah Kotla
# Name: venue, dtype: object

# %%
#q13
a=df.win_by_runs.min()
black=df
c=black.drop(np.where(df.win_by_runs!=a)[0])
set(c.venue)
# Out:
# {'ACA-VDCA Stadium',
#  'Barabati Stadium',
#  'Brabourne Stadium',
#  'Buffalo Park',
#  'De Beers Diamond Oval',
#  'Dr DY Patil Sports Academy',
#  'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#  'Dubai International Cricket Stadium',
#  'Eden Gardens',
#  'Feroz Shah Kotla',
#  'Feroz Shah Kotla Ground',
#  'Green Park',
#  'Himachal Pradesh Cricket Association Stadium',
#  'Holkar Cricket Stadium',
#  'IS Bindra Stadium',
#  'JSCA International Stadium Complex',
#  'Kingsmead',
#  'M Chinnaswamy Stadium',
#  'M. A. Chidambaram Stadium',
#  'M. Chinnaswamy Stadium',
#  'MA Chidambaram Stadium, Chepauk',
#  'Maharashtra Cricket Association Stadium',
#  'Nehru Stadium',
#  'New Wanderers Stadium',
#  'Newlands',
#  'OUTsurance Oval',
#  'Punjab Cricket Association IS Bindra Stadium, Mohali',
#  'Punjab Cricket Association Stadium, Mohali',
#  'Rajiv Gandhi International Stadium, Uppal',
#  'Rajiv Gandhi Intl. Cricket Stadium',
#  'Sardar Patel Stadium, Motera',
# ...

# %%
#q14
#a=df.umpire1.append(df.umpire2).append(df.umpire3).value_counts().to_frame().iloc[0].name
#print(a)
a=df['umpire1'].value_counts()
b=df['umpire2'].value_counts()
c=df['umpire3'].value_counts()
d=c+a+b
# Out:
# count
# 8.0      2
# 19.0     2
# 15.0     2
# 9.0      2
# 16.0     2
# 30.0     1
# 22.0     1
# 83.0     1
# 6.0      1
# 52.0     1
# 26.0     1
# 14.0     1
# 114.0    1
# 7.0      1
# Name: count, dtype: int64

# %%
#q15
df.season.value_counts()

# %%
#q16    
df['id'].where(df['season']==2017)
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
#       ...
# 751    NaN
# 752    NaN
# 753    NaN
# 754    NaN
# 755    NaN
# Name: id, Length: 756, dtype: float64

# %%
#q17
print(df['toss_winner'].value_counts())

# %%
#q18
a=[]
b=[]
d=[]
for r in set(df.season):
    b=np.array(df.toss_decision == 'bat', dtype=np.int0).sum(where=(df.season==r))
    c=np.array(df.toss_decision == 'field', dtype=np.int0).sum(where=(df.season==r))
    a.append(b)
    d.append(c)
    b=[]
    c=[]
e=list(set(df.season))*2
print(e)
position=range(len(a+d))
plt.bar(position,a+d)
plt.xticks(position,e)
#plt.show()
#([2017, 10], [2016, 20], ....)

# %%
#q19
a=fd["dismissal_kind"].value_counts().to_frame().T.columns
b=fd["dismissal_kind"].value_counts()
position=range(len(b))
plt.bar(position,b)
plt.xticks(position,a)

# %%
#q20
a=fd
runs=[]
for r in set(fd.batsman):
    x=np.where(fd.batsman==r)

# %%
#q21
black=df
d=black.drop(np.where(df["player_of_match"].value_counts().to_frame()<3)[0])
e=d["player_of_match"].value_counts()
plt.plot(e)

# %%
#q22
df['team1'].value_counts()+df['team2'].value_counts()
# Out:
# Chennai Super Kings            164
# Deccan Chargers                 75
# Delhi Capitals                  16
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 187
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# Name: count, dtype: int64

# %%
#q23
for r in set(df.winner):
    b=np.array(df.result=='normal',dtype=np.int0).sum(where=(df.winner==r))
    c=np.array(df.result=='tie',dtype=np.int0).sum(where=(df.winner==r))
    d=b+c
    print('the total matches : winning matches : win rate for',r,'is',d,':',b,':',b*100/d)
# Out:
# the total matches : winning matches : win rate for Delhi Capitals is 10 : 9 : 90.0
# the total matches : winning matches : win rate for Kochi Tuskers Kerala is 6 : 6 : 100.0
# the total matches : winning matches : win rate for Gujarat Lions is 13 : 13 : 100.0
# the total matches : winning matches : win rate for Kolkata Knight Riders is 92 : 92 : 100.0
# the total matches : winning matches : win rate for Kings XI Punjab is 82 : 80 : 97.5609756097561
# the total matches : winning matches : win rate for nan is 0 : 0 : nan
# the total matches : winning matches : win rate for Mumbai Indians is 109 : 107 : 98.1651376146789
# the total matches : winning matches : win rate for Chennai Super Kings is 100 : 100 : 100.0
# the total matches : winning matches : win rate for Sunrisers Hyderabad is 58 : 57 : 98.27586206896552
# the total matches : winning matches : win rate for Rising Pune Supergiant is 10 : 10 : 100.0
# ...

# %%
#q24
a=df['winner'].value_counts().to_frame().T.columns
b=df['winner'].value_counts()
plt.plot(b,a)

# %%
#q25
a=df['winner'].value_counts().sum()
x=np.gcd(756,a)
b=756
a=a/x
b=b/x
print('ratio of total matches:win matches is ',b,':',a)
# Out:
# ratio of total matches:win matches is  189.0 : 188.0

# %%
#q26
for r in set(df.toss_winner):
    b=np.array(df.toss_decision=='field',dtype=np.int0).sum(where=(df.toss_winner==r))
    c=np.array(df.toss_decision=='bat',dtype=np.int0).sum(where=(df.toss_winner==r))
    print('the choice of',r,'is to bat',b,'times and field',c,'times')

# %%
df

# %%
fd

# %%
a=fd.groupby(['batsman']).sum()
b=a.sort_values(by='batsman_runs', ascending=False)
b['batsman_runs'].head(10)
# Out:
# batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# Name: batsman_runs, dtype: int64
