# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import EvalCallback,StopTrainingOnRewardThreshold
from stable_baselines3 import DQN

# %%
enviorment_name='CartPole-v0'
env=gym.make(enviorment_name)
# Out:
# /Users/janavbhasin/miniconda3/lib/python3.10/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(

# %%
episodes=5
for episode in range(1,episodes+1):
    state=env.reset()
    done = False
    score=0
    while not done:
        env.render()
        action=env.action_space.sample()
        n_state,reward,done,info,_=env.step(action)
        score=reward+score
    print('episode:{} score:{}'.format(episode,score))
env.close()
# Out:
# episode:1 score:17.0
# episode:2 score:22.0
# episode:3 score:40.0
# episode:4 score:31.0
# episode:5 score:30.0
# /Users/janavbhasin/miniconda3/lib/python3.10/site-packages/gym/envs/classic_control/cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v0", render_mode="rgb_array")
#   gym.logger.warn(

# %%
log_path=os.path.join('Training','Logs')

# %% [markdown]
# # model training

# %%
env=gym.make(enviorment_name)
env=DummyVecEnv([lambda:env])
model=PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# /Users/janavbhasin/miniconda3/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device

# %%
model.learn(total_timesteps=50000)
# Out:
# Logging to Training/Logs/PPO_17
# -----------------------------
# | time/              |      |
# |    fps             | 5576 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4005        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010236053 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.0104     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.76        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 48.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3657         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0068163173 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.67        |
# |    explained_variance   | 0.0718       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.8         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0101      |
# |    value_loss           | 38.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3490        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010273604 |
# |    clip_fraction        | 0.084       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 51.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3380        |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008671398 |
# |    clip_fraction        | 0.0633      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 67.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3314        |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009839804 |
# |    clip_fraction        | 0.0904      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 54.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3266        |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006143583 |
# |    clip_fraction        | 0.0556      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00926    |
# |    value_loss           | 41.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3242         |
# |    iterations           | 8            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0036727637 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.396        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25           |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00572     |
# |    value_loss           | 61.6         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3218       |
# |    iterations           | 9          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01056226 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.572     |
# |    explained_variance   | 0.712      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.38       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.011     |
# |    value_loss           | 28.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3204        |
# |    iterations           | 10          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.002623297 |
# |    clip_fraction        | 0.0279      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.531       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.6        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00513    |
# |    value_loss           | 23.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3192         |
# |    iterations           | 11           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0075026713 |
# |    clip_fraction        | 0.0744       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.547       |
# |    explained_variance   | 0.728        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.15         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00728     |
# |    value_loss           | 23.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3183         |
# |    iterations           | 12           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0061348043 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.285        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.504        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 6.05         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3173        |
# |    iterations           | 13          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.002368589 |
# |    clip_fraction        | 0.0103      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | 0.0313      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.92        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00188    |
# |    value_loss           | 26.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3167        |
# |    iterations           | 14          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005463694 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.537      |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.127       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00475    |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3160        |
# |    iterations           | 15          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005427859 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.235       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00742    |
# |    value_loss           | 1.79        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3158         |
# |    iterations           | 16           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0058341413 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.513       |
# |    explained_variance   | 0.512        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.167        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00408     |
# |    value_loss           | 1.16         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3156         |
# |    iterations           | 17           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0049911104 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | 0.0178       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0752       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00458     |
# |    value_loss           | 0.768        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3154        |
# |    iterations           | 18          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.003180149 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.484      |
# |    explained_variance   | 0.094       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0569      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00187    |
# |    value_loss           | 0.474       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3151         |
# |    iterations           | 19           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0031787935 |
# |    clip_fraction        | 0.00957      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.495       |
# |    explained_variance   | 0.0322       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0488       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000932    |
# |    value_loss           | 0.323        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3147         |
# |    iterations           | 20           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0035044583 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.497       |
# |    explained_variance   | -0.00345     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0715       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000593    |
# |    value_loss           | 0.208        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3146        |
# |    iterations           | 21          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.003128048 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.473      |
# |    explained_variance   | 0.0117      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0335      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 0.137       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3146         |
# |    iterations           | 22           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0018131761 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.488       |
# |    explained_variance   | -0.0125      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0134       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000894    |
# |    value_loss           | 0.0836       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3145         |
# |    iterations           | 23           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0011568755 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.49        |
# |    explained_variance   | 0.015        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00437      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 0.0575       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3144         |
# |    iterations           | 24           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0030210104 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.484       |
# |    explained_variance   | -0.00684     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0022      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000964    |
# |    value_loss           | 0.0377       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3141         |
# |    iterations           | 25           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0014479009 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.471       |
# |    explained_variance   | -0.0208      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0115       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000698    |
# |    value_loss           | 0.0256       |
# ------------------------------------------

# %%
PPO_path=os.path.join('Training','Saved_Models','PPO_Model_Cartpole')

# %%
model.save(PPO_path)

# %%
del model

# %% [markdown]
# # model evaluation

# %%
model=PPO.load(PPO_path,env=env)

# %%
evaluate_policy(model,env,n_eval_episodes=10,render=False)
# Out:
# /Users/janavbhasin/miniconda3/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# # testing the model

# %%
#we are now usingthe previous made model to test the data
episodes=5
for episode in range(1,episodes+1):
    obs=env.reset()
    done = False
    score=0
    while not done:
        env.render()
        action,_=model.predict(obs)
        obs,reward,done,info=env.step(action)
        score=reward+score
    print('episode:{} score:{}'.format(episode,score))
env.close()
# Out:
# episode:1 score:[200.]
# episode:2 score:[200.]
# episode:3 score:[200.]
# episode:4 score:[200.]
# episode:5 score:[200.]
# /Users/janavbhasin/miniconda3/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")

# %%
action,_=model.predict(obs)
env.step(action)
# Out:
# (array([[-0.04338749, -0.23826358,  0.01608197,  0.3087757 ]],
#        dtype=float32),
#  array([1.], dtype=float32),
#  array([False]),
#  [{'TimeLimit.truncated': False}])

# %% [markdown]
# # view logs

# %%
training_log_path=os.path.join(log_path,'PPO_2')
training_log_path
# Out:
# 'Training/Logs/PPO_2'

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.12.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# # adding a call back

# %%
save_path=os.path.join('Training','Saved Models')

# %%
stop_callback=StopTrainingOnRewardThreshold(reward_threshold=200,verbose=1)
eval_callback=EvalCallback(env,
                           callback_on_new_best=stop_callback,
                           eval_freq=10000,
                           best_model_save_path=save_path,
                           verbose=1)

# %%
model=PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000,callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_18
# -----------------------------
# | time/              |      |
# |    fps             | 5688 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 4025       |
# |    iterations           | 2          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00858615 |
# |    clip_fraction        | 0.0919     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.686     |
# |    explained_variance   | -0.0153    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.22       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0142    |
# |    value_loss           | 51.2       |
# ----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 3663     |
# |    iterations           | 3        |
# |    time_elapsed         | 1        |
# |    total_timesteps      | 6144     |
# | train/                  |          |
# |    approx_kl            | 0.010131 |
# |    clip_fraction        | 0.0679   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.667   |
# |    explained_variance   | 0.087    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 11.9     |
# |    n_updates            | 20       |
# |    policy_gradient_loss | -0.0187  |
# |    value_loss           | 33.4     |
# --------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3502         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0076248967 |
# |    clip_fraction        | 0.0708       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.637       |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.8         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0174      |
# |    value_loss           | 56.3         |
# ------------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.009127514 |
# |    clip_fraction        | 0.0652      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.615      |
# |    explained_variance   | 0.291       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 66.8        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200
# /Users/janavbhasin/miniconda3/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
net_arch=[dict(pi=[128,128,128,128],vf=[128,128,128,128])]

# %%
model=PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path,policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device
# /Users/janavbhasin/miniconda3/lib/python3.10/site-packages/stable_baselines3/common/policies.py:484: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
model.learn(total_timesteps=20000,callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_19
# -----------------------------
# | time/              |      |
# |    fps             | 4657 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2515        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015855376 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | -0.000784   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.71        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 20.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2188        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.021111812 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0373     |
# |    value_loss           | 26.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2054        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015285851 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.588      |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0282     |
# |    value_loss           | 37.4        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.018394377 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.88        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 25.3        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1927  |
# |    iterations      | 5     |
# |    time_elapsed    | 5     |
# |    total_timesteps | 10240 |
# ------------------------------
# /Users/janavbhasin/miniconda3/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1890        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009540077 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.527      |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.56        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00624    |
# |    value_loss           | 14.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1867        |
# |    iterations           | 7           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006952006 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.513      |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00579    |
# |    value_loss           | 16.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1851       |
# |    iterations           | 8          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00449436 |
# |    clip_fraction        | 0.0571     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.485     |
# |    explained_variance   | 0.936      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.386      |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.